# %%
import os
import csv
import base64
import requests
from difflib import SequenceMatcher

# %%
#Konfigurasi
LMSTUDIO_API_URL = "http://127.0.0.1:1234/v1/chat/completions"  
SELECTED_MODEL_NAME = "google/gemma-3-4b"
DATASET_DIR = "C:\\Users\\mhafizh.k\\Downloads\\vision\\Indonesian License Plate Recognition Dataset\\images\\test"
LABEL_CSV = "label.csv"
OUTPUT_CSV = "results/ocr_predictions.csv"

# %%
#Fungsi Encode Gambar
from PIL import Image
from io import BytesIO

def encode_image(image_path):
    img = Image.open(image_path)
    img = img.convert("RGB")
    img = img.resize((64, 64))  # Resize agar lebih ringan
    buffered = BytesIO()
    img.save(buffered, format="JPEG")
    return base64.b64encode(buffered.getvalue()).decode("utf-8")


#Hitung CER
def calculate_cer(pred, truth):
    matcher = SequenceMatcher(None, truth, pred)
    edits = 0
    for tag, i1, i2, j1, j2 in matcher.get_opcodes():
        if tag != 'equal':
            edits += max(i2 - i1, j2 - j1)
    return round(edits / max(len(truth), 1), 4)

# %%
#Load Label CSV
def load_ground_truth_from_csv(csv_path):
    gt_map = {}
    try:
        with open(csv_path, mode='r', encoding='utf-8') as file:
            reader = csv.reader(file)
            for row in reader:
                if len(row) >= 2 and "image" not in row[0].lower(): 
                    filename = os.path.basename(row[0]).strip()
                    label = row[1].strip().replace(" ", "").replace("-", "").upper()
                    gt_map[filename] = label
    except Exception as e:
        print(f"❌ Failed to read CSV: {e}")
    return gt_map

# %%
#Kirim Prompt dan Gambar ke LMStudio
def query_model(image_b64):
    payload = {
        "model": SELECTED_MODEL_NAME,
        "messages": [
            {
                "role": "user",
                "content": [
                    {"type": "text", "text": "Berapa nomor plat yang terlihat pada gambar ini? Tanggapi hanya dengan nomor plat-nya."},
                    {"type": "image_url", "image_url": {"url": f"data:image/jpeg;base64,{image_b64}"}}
                ]
            }
        ],
        "temperature": 0.2,
        "stream": False
    }

    headers = {"Content-Type": "application/json"}

    try:
        response = requests.post(LMSTUDIO_API_URL, json=payload, headers=headers, timeout=60)
        if response.status_code == 200:
            result = response.json()
            return result["choices"][0]["message"]["content"].strip()
        else:
            print(f"API Error: {response.status_code} - {response.text}")
            return "ERROR"
    except Exception as e:
        print(f"❌ Request failed: {e}")
        return "ERROR"

# %%
#Fungsi Utama
def main():
    if not os.path.exists(DATASET_DIR):
        print(f"❌ Dataset folder tidak ditemukan: {DATASET_DIR}")
        return

    os.makedirs("results", exist_ok=True)
    labels = load_ground_truth_from_csv(LABEL_CSV)

    with open(OUTPUT_CSV, "w", newline='', encoding='utf-8') as out_csv:
        writer = csv.writer(out_csv)
        writer.writerow(["image", "ground_truth", "prediction", "CER_score"])

        total, errors, scores = 0, 0, []

        for fname in sorted(os.listdir(DATASET_DIR)):
            if not fname.lower().endswith((".jpg", ".jpeg", ".png")):
                continue
            if fname not in labels:
                print(f"⚠️ No label for {fname}, skipped.")
                continue

            path = os.path.join(DATASET_DIR, fname)
            gt = labels[fname]
            print(f"📸 {fname}...")

            try:
                image_b64 = encode_image(path)
                pred = query_model(image_b64)
                pred = pred.replace(" ", "").replace("-", "").upper()
                cer = calculate_cer(pred, gt)
                writer.writerow([fname, gt, pred, cer])
                print(f"✅ GT: {gt} | Pred: {pred} | CER: {cer}")
                scores.append(cer)
                total += 1
            except Exception as e:
                print(f"❌ Error on {fname}: {e}")
                writer.writerow([fname, gt, "ERROR", 1.0])
                errors += 1

        if scores:
            avg = sum(scores) / len(scores)
            print(f"\n📈 Average CER: {avg:.4f}")
        print(f"\n🎉 Done! Processed: {total}, Errors: {errors}")


if __name__ == "__main__":
    main()
# Out:
# 📸 test001_1.jpg...
# ✅ GT: B9140BCD | Pred: S140BCD | CER: 0.25
# 📸 test001_2.jpg...
# ✅ GT: B2407UZO | Pred: B2407UZO | CER: 0.0
# 📸 test001_3.jpg...
# ✅ GT: B2642PKM | Pred: 2842PKM | CER: 0.25
# 📸 test002_1.jpg...
# ✅ GT: BG1352AE | Pred: 1352 | CER: 0.5
# 📸 test003_1.jpg...
# ✅ GT: B2634UZF | Pred: 2634 | CER: 0.5
# 📸 test003_2.jpg...
# ✅ GT: B1995JVK | Pred: B1995JVK | CER: 0.0
# 📸 test004_1.jpg...
# ✅ GT: B9062VEH | Pred: 389756 | CER: 1.0
# 📸 test005_1.jpg...
# ✅ GT: DD3798KM | Pred: 798 | CER: 0.625
# 📸 test006_1.jpg...
# ✅ GT: T1329KC | Pred: 1329 | CER: 0.4286
# 📸 test007_1.jpg...
# ✅ GT: AD8865EE | Pred: AD8665EE | CER: 0.125
# 📸 test008_1.jpg...
# ✅ GT: DK1157AAB | Pred: 1157AAB | CER: 0.2222
# 📸 test008_2.jpg...
# ✅ GT: AA1997FE | Pred: 1997FE | CER: 0.25
# 📸 test009_1.jpg...
# ✅ GT: H8518NA | Pred: 8518 | CER: 0.4286
# 📸 test009_2.jpg...
# ✅ GT: K1649GB | Pred: 1649GB | CER: 0.1429
# 📸 test010_1.jpg...
# ✅ GT: B9416PCN | Pred: B9416PCN | CER: 0.0
# 📸 test010_2.jpg...
# ✅ GT: H1147UY | Pred: H147UY | CER: 0.1429
# 📸 test011_1.jpg...
# ✅ GT: H1691IL | Pred: H1691IL | CER: 0.0
# 📸 test011_2.jpg...
# ✅ GT: B9374RI | Pred: PB8314RV | CER: 0.5714
# 📸 test011_3.jpg...
# ✅ GT: D1204AIG | Pred: D1204AIG | CER: 0.0
# 📸 test012_1.jpg...
# ✅ GT: E1887BA | Pred: 1887 | CER: 0.4286
# 📸 test013_1.jpg...
# ✅ GT: B1439UZP | Pred: 1439UZP | CER: 0.125
# 📸 test013_2.jpg...
# ✅ GT: B1128W0S | Pred: 1128 | CER: 0.5
# 📸 test014_1.jpg...
# ✅ GT: B1388DFX | Pred: 1388 | CER: 0.5
# 📸 test015_1.jpg...
# ✅ GT: AD1898BT | Pred: 1798BT | CER: 0.375
# 📸 test016_1.jpg...
# ✅ GT: E1517DQ | Pred: E151700 | CER: 0.2857
# 📸 test017_1.jpg...
# ✅ GT: AD8982FS | Pred: 8982 | CER: 0.5
# 📸 test018_1.jpg...
# ✅ GT: L7603UA | Pred: 7603UA | CER: 0.1429
# 📸 test019_1.jpg...
# ✅ GT: AD7HS | Pred: AD7HS2224 | CER: 0.8
# 📸 test019_2.jpg...
# ✅ GT: B1959WYK | Pred: 1959HYK | CER: 0.25
# 📸 test020_1.jpg...
# ✅ GT: AG8634EK | Pred: AG8694 | CER: 0.375
# 📸 test020_2.jpg...
# ✅ GT: AD1329PY | Pred: 1328 | CER: 0.625
# 📸 test021_1.jpg...
# ✅ GT: BA1709DW | Pred: 1709 | CER: 0.5
# 📸 test021_2.jpg...
# ✅ GT: W1236VZ | Pred: 1236 | CER: 0.4286
# 📸 test022_1.jpg...
# ✅ GT: W1825OZ | Pred: 18250Z | CER: 0.2857
# 📸 test022_2.jpg...
# ✅ GT: L1202UE | Pred: L202UE | CER: 0.1429
# 📸 test022_3.jpg...
# ✅ GT: L3823IB | Pred: 3823100226 | CER: 1.0
# 📸 test023_1.jpg...
# ✅ GT: B1730JLO | Pred: B1730JLO | CER: 0.0
# 📸 test024_1.jpg...
# ✅ GT: B2964TRU | Pred: 2964 | CER: 0.5
# 📸 test025_1.jpg...
# ✅ GT: S5585LP | Pred: 5585 | CER: 0.4286
# 📸 test025_2.jpg...
# ✅ GT: L2858RR | Pred: L2858RR | CER: 0.0
# 📸 test025_3.jpg...
# ✅ GT: W1185ZO | Pred: 1165Z0 | CER: 0.4286
# 📸 test025_4.jpg...
# ✅ GT: 9840VU | Pred: 9840VU | CER: 0.0
# 📸 test026_1.jpg...
# ✅ GT: N9652DF | Pred: 9652 | CER: 0.4286
# 📸 test026_2.jpg...
# ✅ GT: L3836ZX | Pred: 3836ZX | CER: 0.1429
# 📸 test027_1.jpg...
# ✅ GT: N1905IG | Pred: 1905IG | CER: 0.1429
# 📸 test027_2.jpg...
# ✅ GT: B1109CLR | Pred: 1169 | CER: 0.625
# 📸 test027_3.jpg...
# ✅ GT: L1840AA | Pred: 1840 | CER: 0.4286
# 📸 test028_1.jpg...
# ✅ GT: L1438EO | Pred: 1438E0 | CER: 0.2857
# 📸 test028_2.jpg...
# ✅ GT: 1436AAA | Pred: L1436AAA | CER: 0.1429
# 📸 test029_1.jpg...
# ✅ GT: W1518WF | Pred: 1516 | CER: 0.5714
# 📸 test029_2.jpg...
# ❌ Request failed: HTTPConnectionPool(host='127.0.0.1', port=1234): Read timed out. (read timeout=60)
# ✅ GT: G1986N | Pred: ERROR | CER: 1.0
# 📸 test029_3.jpg...
# ✅ GT: L1588OO | Pred: 158800 | CER: 0.4286
# 📸 test029_4.jpg...
# ✅ GT: L1436AAA | Pred: L1436 | CER: 0.375
# 📸 test030_1.jpg...
# ✅ GT: S8062NF | Pred: 8062 | CER: 0.4286
# 📸 test030_2.jpg...
# ❌ Request failed: HTTPConnectionPool(host='127.0.0.1', port=1234): Read timed out. (read timeout=60)
# ✅ GT: G1894TE | Pred: ERROR | CER: 1.4286
# 📸 test031_1.jpg...
# ❌ Request failed: HTTPConnectionPool(host='127.0.0.1', port=1234): Read timed out. (read timeout=60)
# ✅ GT: L1560JQ | Pred: ERROR | CER: 1.0
# 📸 test031_2.jpg...
# ❌ Request failed: HTTPConnectionPool(host='127.0.0.1', port=1234): Read timed out. (read timeout=60)
# ✅ GT: L1568Q0 | Pred: ERROR | CER: 1.0
# 📸 test031_3.jpg...
# ✅ GT: L1932AAZ | Pred: 1332A12 | CER: 0.5
# 📸 test032_1.jpg...
# ✅ GT: B2754SKY | Pred: 2754 | CER: 0.5
# 📸 test032_2.jpg...
# ✅ GT: W1192K | Pred: 1192 | CER: 0.3333
# 📸 test033_1.jpg...
# ✅ GT: L4561VK | Pred: 4561 | CER: 0.4286
# 📸 test033_2.jpg...
# ✅ GT: L2693GA | Pred: 2693 | CER: 0.4286
# 📸 test033_3.jpg...
# ✅ GT: W9847G | Pred: 6412 | CER: 0.8333
# 📸 test033_4.jpg...
# ✅ GT: L1762ABJ | Pred: 1762ABJ | CER: 0.125
# 📸 test034_1.jpg...
# ✅ GT: L1811SU | Pred: 18111 | CER: 0.4286
# 📸 test034_2.jpg...
# ✅ GT: W1167V0 | Pred: 1167 | CER: 0.4286
# 📸 test034_3.jpg...
# ✅ GT: S61310CF | Pred: S613722 | CER: 0.5
# 📸 test034_4.jpg...
# ✅ GT: L2570AAD | Pred: L2570AAD | CER: 0.0
# 📸 test035_1.jpg...
# ✅ GT: L9643NN | Pred: 9643 | CER: 0.4286
# 📸 test035_2.jpg...
# ✅ GT: L5247GI | Pred: 5267 | CER: 0.5714
# 📸 test035_3.jpg...
# ✅ GT: L2498AAM | Pred: 2498 | CER: 0.5
# 📸 test035_4.jpg...
# ✅ GT: W1696YO | Pred: W1696YO | CER: 0.0
# 📸 test036_1.jpg...
# ✅ GT: B1231JJA | Pred: 1231JJA | CER: 0.125
# 📸 test036_2.jpg...
# ✅ GT: B1618UAE | Pred: BIG18UAE | CER: 0.25
# 📸 test037_1.jpg...
# ✅ GT: L1775V0 | Pred: 1775VO8 | CER: 0.4286
# 📸 test037_2.jpg...
# ✅ GT: L300RX | Pred: 300RX | CER: 0.1667
# 📸 test037_3.jpg...
# ✅ GT: L1879VG | Pred: 1879 | CER: 0.4286
# 📸 test038_1.jpg...
# ✅ GT: D1523YCN | Pred: 1523YCH | CER: 0.25
# 📸 test038_2.jpg...
# ✅ GT: L1877ACU | Pred: 1877ACU | CER: 0.125
# 📸 test039_1.jpg...
# ✅ GT: L1069VK | Pred: 1059VY | CER: 0.4286
# 📸 test040_1.jpg...
# ✅ GT: S1595LL | Pred: 1595LL | CER: 0.1429
# 📸 test041_1.jpg...
# ✅ GT: B1231JJA | Pred: 123JJJA | CER: 0.25
# 📸 test042_1.jpg...
# ✅ GT: AD1174SF | Pred: 1174SF | CER: 0.25
# 📸 test043_1.jpg...
# ✅ GT: W1898YW | Pred: 1898 | CER: 0.4286
# 📸 test043_2.jpg...
# ✅ GT: W1470PG | Pred: 1470 | CER: 0.4286
# 📸 test044_1.jpg...
# ✅ GT: L1930KF | Pred: 1930KF | CER: 0.1429
# 📸 test044_2.jpg...
# ✅ GT: N1004HE | Pred: 1004 | CER: 0.4286
# 📸 test045_1.jpg...
# ✅ GT: S1347LJ | Pred: 1347LJ | CER: 0.1429
# 📸 test046_1.jpg...
# ✅ GT: L1470ABK | Pred: 1470ABK | CER: 0.125
# 📸 test046_2.jpg...
# ✅ GT: L1265MX | Pred: 1265HX | CER: 0.2857
# 📸 test047_1.jpg...
# ✅ GT: N1524SY | Pred: 1524 | CER: 0.4286
# 📸 test047_2.jpg...
# ✅ GT: L1678ACE | Pred: 1678 | CER: 0.5
# 📸 test048_1.jpg...
# ✅ GT: L9316BC | Pred: 9316 | CER: 0.4286
# 📸 test048_2.jpg...
# ✅ GT: W1838AY | Pred: 1838 | CER: 0.4286
# 📸 test049_1.jpg...
# ✅ GT: N1376DE | Pred: 1376 | CER: 0.4286
# 📸 test049_2.jpg...
# ✅ GT: N79AP | Pred: 792P | CER: 0.4
# 📸 test050_1.jpg...
# ✅ GT: L1265OF | Pred: 1265OF | CER: 0.1429
# 📸 test050_2.jpg...
# ✅ GT: N1095G | Pred: 10956 | CER: 0.3333
#
# 📈 Average CER: 0.3715
#
# 🎉 Done! Processed: 98, Errors: 0
